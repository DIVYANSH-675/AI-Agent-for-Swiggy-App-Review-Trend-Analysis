# %% [markdown]
# # Topic Canonicalization Workflow
# Consolidate NOVEL topics into the registry using embeddings + LLM review.

# %%
import polars as pl
from pathlib import Path
import json
from datetime import datetime
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from utils.llm_client import LLMClient

DATA_DIR = Path('../data')
REGISTRY_PATH = Path('../registry/topic_registry.json')
MODEL_NAME = 'all-MiniLM-L6-v2'
SIM_THRESHOLD = 0.82
LLM_PROVIDER = 'megallm'
LLM_MODEL = 'gpt-4o-mini'

print('✓ Environment ready')
# Out:
# ✓ Environment ready

# %% [markdown]
# ## Load Registry and Novel Candidates

# %%
with open(REGISTRY_PATH) as f:
    registry = json.load(f)

registry_version = registry.get('version', 'unknown')
registry_created = registry.get('created_at')
existing_topics = registry['topics']
print(f"Loaded {len(existing_topics)} registry topics (version {registry_version}, created {registry_created})")

novel_frames = []
for path in sorted((DATA_DIR / 'daily_labels').glob('labels_*.parquet')):
    df = pl.read_parquet(path)
    novel_subset = df.filter((pl.col('topic_id') == 'NOVEL') & pl.col('novel_label').is_not_null())
    if len(novel_subset) > 0:
        novel_frames.append(novel_subset)

if not novel_frames:
    raise ValueError('No NOVEL topics found to canonicalize.')

novel_df = pl.concat(novel_frames).with_columns([
    pl.col('created_at').dt.convert_time_zone('Asia/Kolkata'),
]).unique(subset=['novel_label'])
print(f'Found {len(novel_df)} unique novel candidates')
# Out:
# Loaded 32 registry topics (version 001, created 2025-10-27T00:00:00+05:30)
# Found 1028 unique novel candidates

# %% [markdown]
# ## Summarize Novel Candidates

# %%
# Summarize novel topics by frequency and recency
novel_summary = novel_df.group_by('novel_label').agg([
    pl.len().alias('review_count'),
    pl.first('novel_rationale').alias('sample_rationale'),
    pl.min('created_at').alias('first_seen'),
    pl.max('created_at').alias('last_seen'),
]).sort('review_count', descending=True)

print(f"✓ Aggregated {len(novel_summary)} novel topic candidates")
summary_path = DATA_DIR / 'novel_topic_summary.parquet'
novel_summary.write_parquet(summary_path)
print(f"  Saved summary to {summary_path}")

try:
    display(novel_summary.head(10))
except NameError:
    print(novel_summary.head(10))
# Out:
# ✓ Aggregated 1028 novel topic candidates
#   Saved summary to ../data/novel_topic_summary.parquet
# shape: (10, 5)
# ┌──────────────────────┬──────────────┬──────────────────────┬───────────────┬─────────────────────┐
# │ novel_label          ┆ review_count ┆ sample_rationale     ┆ first_seen    ┆ last_seen           │
# │ ---                  ┆ ---          ┆ ---                  ┆ ---           ┆ ---                 │
# │ str                  ┆ u32          ┆ str                  ┆ datetime[μs,  ┆ datetime[μs,        │
# │                      ┆              ┆                      ┆ Asia/Kolkata] ┆ Asia/Kolkata]       │
# ╞══════════════════════╪══════════════╪══════════════════════╪═══════════════╪═════════════════════╡
# │ Request for delivery ┆ 1            ┆ The review is a      ┆ 2025-10-25    ┆ 2025-10-25 16:29:17 │
# │                      ┆              ┆ simple request…      ┆ 16:29:17 IST  ┆ IST                 │
# │ Unrelated Review     ┆ 1            ┆ The review does not  ┆ 2025-10-11    ┆ 2025-10-11 17:24:26 │
# │ Content              ┆              ┆ relate to …          ┆ 17:24:26 IST  ┆ IST                 │
# │ Disappointment with  ┆ 1            ┆ The review expresses ┆ 2025-10-18    ┆ 2025-10-18 14:24:24 │
# │ medicine o…          ┆              ┆ disappoin…           ┆ 14:24:24 IST  ┆ IST                 │
# │ Request for better   ┆ 1            ┆ The review suggests  ┆ 2025-09-29    ┆ 2025-09-29 17:57:36 │
# │ offers               ┆              ┆ improving …          ┆ 17:57:36 IST  ┆ IST                 │
# │ Awesome Offers       ┆ 1            ┆ The review mentions  ┆ 2025-10-05    ┆ 2025-10-05 09:18:24 │
# │                      ┆              ┆ awesome of…          ┆ 09:18:24 IST  ┆ IST                 │
# │ Poor Delivery        ┆ 1            ┆ The term 'bakwaas    ┆ 2025-10-06    ┆ 2025-10-06 10:11:32 │
# │ Experience           ┆              ┆ delivery' in…        ┆ 10:11:32 IST  ┆ IST                 │
# │ Positive feedback on ┆ 1            ┆ The review mentions  ┆ 2025-10-20    ┆ 2025-10-20 16:39:06 │
# │ deals                ┆              ┆ 'great dea…          ┆ 16:39:06 IST  ┆ IST                 │
# │ App Deletion         ┆ 1            ┆ User deleted the app ┆ 2025-10-25    ┆ 2025-10-25 14:27:35 │
# │ Experience           ┆              ┆ due to di…           ┆ 14:27:35 IST  ┆ IST                 │
# │ Lack of offers       ┆ 1            ┆ The review mentions  ┆ 2025-10-08    ┆ 2025-10-08 05:33:39 │
# │                      ┆              ┆ a lack of …          ┆ 05:33:39 IST  ┆ IST                 │
# │ Account Deletion     ┆ 1            ┆ User unable to       ┆ 2025-10-13    ┆ 2025-10-13 07:55:36 │
# │ Issue                ┆              ┆ delete account …     ┆ 07:55:36 IST  ┆ IST                 │
# └──────────────────────┴──────────────┴──────────────────────┴───────────────┴─────────────────────┘

# %% [markdown]
# ## Compute Embeddings and Similarities

# %%
import time

model = SentenceTransformer(MODEL_NAME)
print(f"✓ Loaded embedding model {MODEL_NAME}")

# Build the registry corpus
registry_corpus = [topic['name'] + ' ' + topic['definition'] for topic in existing_topics]
print(f"[LOG] Constructed registry_corpus: {len(registry_corpus)} entries")

# Encode registry topics
start_time = time.time()
registry_matrix = model.encode(registry_corpus, show_progress_bar=True)
elapsed = time.time() - start_time
print(f"[LOG] Encoded registry_corpus into registry_matrix with shape {registry_matrix.shape} in {elapsed:.2f}s")

# Prepare novel texts
novel_texts = [
    f"{row['novel_label']} :: {row['novel_rationale']}" if row['novel_rationale'] else row['novel_label']
    for row in novel_df.iter_rows(named=True)
]
print(f"[LOG] Constructed novel_texts: {len(novel_texts)} entries")

# Encode novel texts
start_time = time.time()
novel_matrix = model.encode(novel_texts, show_progress_bar=True)
elapsed = time.time() - start_time
print(f"[LOG] Encoded novel_texts into novel_matrix with shape {novel_matrix.shape} in {elapsed:.2f}s")

# Compute cosine similarities
start_time = time.time()
similarities = cosine_similarity(novel_matrix, registry_matrix)
elapsed = time.time() - start_time
print(f"[LOG] Computed cosine_similarity matrix with shape {similarities.shape} in {elapsed:.2f}s")

# Build candidate matches
candidate_matches = []
print("[LOG] Beginning to iterate through novel rows for matching…")
for idx, novel_row in enumerate(novel_df.iter_rows(named=True)):
    sim_row = similarities[idx]
    best_idx = int(sim_row.argmax())
    best_score = float(sim_row[best_idx])
    registry_topic = existing_topics[best_idx]
    candidate = {
        'novel_label': novel_row['novel_label'],
        'novel_rationale': novel_row['novel_rationale'],
        'first_seen': novel_row['created_at'],
        'best_topic_id': registry_topic['id'],
        'best_topic_name': registry_topic['name'],
        'similarity': best_score
    }
    candidate_matches.append(candidate)

    # Detailed log per row (optional: comment out for huge datasets)
    print(f"[LOG][row {idx}] novel_label='{candidate['novel_label']}' → "
          f"best_topic_id='{candidate['best_topic_id']}', "
          f"best_topic_name='{candidate['best_topic_name']}', "
          f"similarity={candidate['similarity']:.4f}")

print(f"[LOG] Built {len(candidate_matches)} candidate matches")

candidate_df = pl.DataFrame(candidate_matches).sort('similarity', descending=True)
print(f"✓ Candidate matches computed ({len(candidate_df)} rows)")

try:
    display(candidate_df.head(10))
except NameError:
    print(candidate_df.head(10))
# Out:
# ✓ Loaded embedding model all-MiniLM-L6-v2
# [LOG] Constructed registry_corpus: 32 entries
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [LOG] Encoded registry_corpus into registry_matrix with shape (32, 384) in 0.20s
# [LOG] Constructed novel_texts: 1028 entries
# Batches:   0%|          | 0/33 [00:00<?, ?it/s]
# [LOG] Encoded novel_texts into novel_matrix with shape (1028, 384) in 0.35s
# [LOG] Computed cosine_similarity matrix with shape (1028, 32) in 0.00s
# [LOG] Beginning to iterate through novel rows for matching…
# [LOG][row 0] novel_label='Restaurant policy on offers' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.4673
# [LOG][row 1] novel_label='Weird payment option' → best_topic_id='MONEY_ALREADY_EATEN', best_topic_name='Money Already Eaten', similarity=0.4296
# [LOG][row 2] novel_label='Unclear review context' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.2047
# [LOG][row 3] novel_label='Promotional Offer Mentioned' → best_topic_id='OVERPRICED_ITEMS', best_topic_name='Overpriced Items', similarity=0.2944
# [LOG][row 4] novel_label='Service Issue' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4307
# [LOG][row 5] novel_label='Hunger Issue' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.3976
# [LOG][row 6] novel_label='Reporting restaurant issues' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.4938
# [LOG][row 7] novel_label='Single pizza order' → best_topic_id='WRONG_ITEM', best_topic_name='Wrong Item', similarity=0.3359
# [LOG][row 8] novel_label='App Update Usability Issue' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5064
# [LOG][row 9] novel_label='Waiting for update' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.4111
# [LOG][row 10] novel_label='Need for more offers' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.3375
# [LOG][row 11] novel_label='Blacklist Request' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.3147
# [LOG][row 12] novel_label='Generic apology' → best_topic_id='NEGATIVE_GENERIC', best_topic_name='Negative Generic', similarity=0.3618
# [LOG][row 13] novel_label='Unclear Responsibility' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.2764
# [LOG][row 14] novel_label='Dinecash service issue' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2897
# [LOG][row 15] novel_label='Faster booking and delivery' → best_topic_id='FAST_DELIVERY', best_topic_name='Fast Delivery', similarity=0.6448
# [LOG][row 16] novel_label='Discount Comparison' → best_topic_id='OVERPRICED_ITEMS', best_topic_name='Overpriced Items', similarity=0.3636
# [LOG][row 17] novel_label='Slow App Response' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5628
# [LOG][row 18] novel_label='Scam App' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.3868
# [LOG][row 19] novel_label='Customer Food Safety Concern' → best_topic_id='PACKAGING_LEAK', best_topic_name='Packaging Leak', similarity=0.4337
# [LOG][row 20] novel_label='Request for menu filter' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.4611
# [LOG][row 21] novel_label='App performance issue' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.4395
# [LOG][row 22] novel_label='High rating without context' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3007
# [LOG][row 23] novel_label='Positive service feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.8405
# [LOG][row 24] novel_label='Membership Misleading Pricing' → best_topic_id='HIGH_FEES', best_topic_name='High Fees', similarity=0.5016
# [LOG][row 25] novel_label='Health Risk from Food' → best_topic_id='PACKAGING_LEAK', best_topic_name='Packaging Leak', similarity=0.4406
# [LOG][row 26] novel_label='Order Cancellation Issue' → best_topic_id='NO_CANCEL_OPTION', best_topic_name='No Cancel Option', similarity=0.6042
# [LOG][row 27] novel_label='Celebrity Hiring Concern' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.2529
# [LOG][row 28] novel_label='Item Pricing Transparency' → best_topic_id='OVERPRICED_ITEMS', best_topic_name='Overpriced Items', similarity=0.4781
# [LOG][row 29] novel_label='Marketing vs Customer Benefits' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5511
# [LOG][row 30] novel_label='Coupon Code Limitation' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.2825
# [LOG][row 31] novel_label='Automatic Order Issue' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.4293
# [LOG][row 32] novel_label='Discount Mentioned' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.2382
# [LOG][row 33] novel_label='Payment concern' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3894
# [LOG][row 34] novel_label='Free food promotion' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.3763
# [LOG][row 35] novel_label='Order Placement Issue' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.4505
# [LOG][row 36] novel_label='Better Offers Comparison' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.6138
# [LOG][row 37] novel_label='Request for Fireworks' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.1956
# [LOG][row 38] novel_label='Hot food not provided' → best_topic_id='STALE_FOOD', best_topic_name='Stale Food', similarity=0.4036
# [LOG][row 39] novel_label='Request for vouchers' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.3356
# [LOG][row 40] novel_label='Menu Navigation Improvement' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.2905
# [LOG][row 41] novel_label='Generic greeting' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4404
# [LOG][row 42] novel_label='Positive feedback on patience' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4932
# [LOG][row 43] novel_label='Service Improvement Needed' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4552
# [LOG][row 44] novel_label='Review System Issues' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.4137
# [LOG][row 45] novel_label='Quantity Concern' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.3177
# [LOG][row 46] novel_label='Website Usability Issue' → best_topic_id='CART_BUG', best_topic_name='Cart Bug', similarity=0.2326
# [LOG][row 47] novel_label='Order Issue' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.5050
# [LOG][row 48] novel_label='Earning payout concerns' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3077
# [LOG][row 49] novel_label='Biryani Mentioned' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.1424
# [LOG][row 50] novel_label='Client Communication Issue' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.4100
# [LOG][row 51] novel_label='Generic Feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5209
# [LOG][row 52] novel_label='Free cash usage issue' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.4451
# [LOG][row 53] novel_label='Positive feedback on dishes' → best_topic_id='GOOD_QUALITY_FOOD', best_topic_name='Good Quality Food', similarity=0.5901
# [LOG][row 54] novel_label='Expired Items Received' → best_topic_id='STALE_FOOD', best_topic_name='Stale Food', similarity=0.3883
# [LOG][row 55] novel_label='Payment Mode Inquiry' → best_topic_id='PAYMENT_FAILURE', best_topic_name='Payment Failure', similarity=0.4265
# [LOG][row 56] novel_label='Coupon Application Issue' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.3261
# [LOG][row 57] novel_label='Herbal food mention' → best_topic_id='GOOD_QUALITY_FOOD', best_topic_name='Good Quality Food', similarity=0.4447
# [LOG][row 58] novel_label='General dissatisfaction with app' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5595
# [LOG][row 59] novel_label='App images not loading' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.3727
# [LOG][row 60] novel_label='Slow Payment Process' → best_topic_id='MONEY_ALREADY_EATEN', best_topic_name='Money Already Eaten', similarity=0.4365
# [LOG][row 61] novel_label='Order Quantity Confusion' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.4974
# [LOG][row 62] novel_label='App Bugs' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.4743
# [LOG][row 63] novel_label='Gaming Reference' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.3484
# [LOG][row 64] novel_label='No discounts for new users' → best_topic_id='LOGIN_BUG', best_topic_name='Login Bug', similarity=0.2555
# [LOG][row 65] novel_label='App Feedback' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.6151
# [LOG][row 66] novel_label='Request for improvement' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5234
# [LOG][row 67] novel_label='Delivery Partner Issue' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.5142
# [LOG][row 68] novel_label='General Food Appreciation' → best_topic_id='GOOD_QUALITY_FOOD', best_topic_name='Good Quality Food', similarity=0.5588
# [LOG][row 69] novel_label='Service Tier Issues' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4692
# [LOG][row 70] novel_label='Poor Service Feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.6738
# [LOG][row 71] novel_label='Silent COD switch exploitation' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.6352
# [LOG][row 72] novel_label='Ease of Movement' → best_topic_id='FAST_DELIVERY', best_topic_name='Fast Delivery', similarity=0.2176
# [LOG][row 73] novel_label='Lazypay Account Linking Issue' → best_topic_id='LOGIN_BUG', best_topic_name='Login Bug', similarity=0.3543
# [LOG][row 74] novel_label='Bulk order delivery issue' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.5359
# [LOG][row 75] novel_label='App issues affecting delivery' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.4683
# [LOG][row 76] novel_label='Satvik food options' → best_topic_id='GOOD_QUALITY_FOOD', best_topic_name='Good Quality Food', similarity=0.3480
# [LOG][row 77] novel_label='Ad annoyance issue' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2682
# [LOG][row 78] novel_label='Delivery Service Reference' → best_topic_id='CANT_FIND_ADDRESS', best_topic_name='Can't Find Address', similarity=0.4817
# [LOG][row 79] novel_label='Marketing Feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4437
# [LOG][row 80] novel_label='App performance issues' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5430
# [LOG][row 81] novel_label='Delivery partner concerns ignored' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.4977
# [LOG][row 82] novel_label='Instamart availability issue' → best_topic_id='OUT_OF_STOCK', best_topic_name='Out of Stock', similarity=0.2314
# [LOG][row 83] novel_label='Free Delivery Not Provided' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.4782
# [LOG][row 84] novel_label='Account Reactivation Request' → best_topic_id='LOGIN_BUG', best_topic_name='Login Bug', similarity=0.3260
# [LOG][row 85] novel_label='Frequent Ordering Issue' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.4175
# [LOG][row 86] novel_label='GST Complaint' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.4235
# [LOG][row 87] novel_label='Eatlist visibility issue' → best_topic_id='STALE_FOOD', best_topic_name='Stale Food', similarity=0.3396
# [LOG][row 88] novel_label='Lack of Offers' → best_topic_id='OUT_OF_STOCK', best_topic_name='Out of Stock', similarity=0.4197
# [LOG][row 89] novel_label='Improper Offer' → best_topic_id='NO_CANCEL_OPTION', best_topic_name='No Cancel Option', similarity=0.3170
# [LOG][row 90] novel_label='Emotional response' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3931
# [LOG][row 91] novel_label='Generic positive greeting' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5965
# [LOG][row 92] novel_label='Positive feedback on product' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5928
# [LOG][row 93] novel_label='Unclear Delivery Communication' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.5283
# [LOG][row 94] novel_label='Removal of Eatlist Option' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.2903
# [LOG][row 95] novel_label='Fraudulent service complaint' → best_topic_id='HIGH_FEES', best_topic_name='High Fees', similarity=0.4199
# [LOG][row 96] novel_label='Positive sentiment without details' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5219
# [LOG][row 97] novel_label='Pizza mention' → best_topic_id='GOOD_QUALITY_FOOD', best_topic_name='Good Quality Food', similarity=0.2916
# [LOG][row 98] novel_label='Request for coupons' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3512
# [LOG][row 99] novel_label='Order Cancellation Without Notice' → best_topic_id='NO_CANCEL_OPTION', best_topic_name='No Cancel Option', similarity=0.5309
# [LOG][row 100] novel_label='Emotional Discontent' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3217
# [LOG][row 101] novel_label='App not opening' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.4312
# [LOG][row 102] novel_label='Delivery person payment issue' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.6450
# [LOG][row 103] novel_label='Coupon Usage Issue' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.3921
# [LOG][row 104] novel_label='Rude Customer Interaction' → best_topic_id='RUDE_DELIVERY_PERSON', best_topic_name='Rude Delivery Person', similarity=0.4563
# [LOG][row 105] novel_label='Genie feature request' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2713
# [LOG][row 106] novel_label='Unclear service description' → best_topic_id='HIGH_FEES', best_topic_name='High Fees', similarity=0.3133
# [LOG][row 107] novel_label='Ambiguous sentiment' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4329
# [LOG][row 108] novel_label='Delivery Status Inquiry' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.5836
# [LOG][row 109] novel_label='App Glitches and Lags' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.4418
# [LOG][row 110] novel_label='Food quality expectation' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.6699
# [LOG][row 111] novel_label='Location Verification Issue' → best_topic_id='CANT_FIND_ADDRESS', best_topic_name='Can't Find Address', similarity=0.4843
# [LOG][row 112] novel_label='Time-saving service' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4454
# [LOG][row 113] novel_label='Emojis Only Review' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2770
# [LOG][row 114] novel_label='Insulting star rating' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2811
# [LOG][row 115] novel_label='User Name Mentioned' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2854
# [LOG][row 116] novel_label='Feedback request process' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5677
# [LOG][row 117] novel_label='Request for best offer' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.2789
# [LOG][row 118] novel_label='Insufficient Delivery Executives' → best_topic_id='RUDE_DELIVERY_PERSON', best_topic_name='Rude Delivery Person', similarity=0.5159
# [LOG][row 119] novel_label='Comparison with Zepto' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.2697
# [LOG][row 120] novel_label='Penalty Related Issue' → best_topic_id='NEGATIVE_GENERIC', best_topic_name='Negative Generic', similarity=0.2723
# [LOG][row 121] novel_label='Delivery Partner Restrictions' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.5301
# [LOG][row 122] novel_label='Invoice Header Issue' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.3102
# [LOG][row 123] novel_label='Driver Assistance' → best_topic_id='BOT_ONLY_NO_HUMAN', best_topic_name='Bot Only No Human Support', similarity=0.2473
# [LOG][row 124] novel_label='Positive food feedback' → best_topic_id='GOOD_QUALITY_FOOD', best_topic_name='Good Quality Food', similarity=0.6501
# [LOG][row 125] novel_label='Romantic sentiment' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.4478
# [LOG][row 126] novel_label='Delivery Partner Identity' → best_topic_id='CANT_FIND_ADDRESS', best_topic_name='Can't Find Address', similarity=0.4588
# [LOG][row 127] novel_label='Timing and money issues' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.4020
# [LOG][row 128] novel_label='First Experience Feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5285
# [LOG][row 129] novel_label='Candle offer complaint' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.3134
# [LOG][row 130] novel_label='Poor Offers Compared to Competitors' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.4217
# [LOG][row 131] novel_label='Coupon Improvement Suggestion' → best_topic_id='OVERPRICED_ITEMS', best_topic_name='Overpriced Items', similarity=0.2361
# [LOG][row 132] novel_label='Order Status Inquiry' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.4500
# [LOG][row 133] novel_label='Unclear sentiment' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3872
# [LOG][row 134] novel_label='Jewelry dissatisfaction' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3178
# [LOG][row 135] novel_label='Negative sentiment towards company' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4652
# [LOG][row 136] novel_label='Lack of Discount Coupons' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.3018
# [LOG][row 137] novel_label='Ambiguous review sentiment' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4776
# [LOG][row 138] novel_label='Membership dissatisfaction' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3785
# [LOG][row 139] novel_label='Positive feedback on offers' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5706
# [LOG][row 140] novel_label='Delivery Information Issue' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.5280
# [LOG][row 141] novel_label='Unrecognized member offers' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.3344
# [LOG][row 142] novel_label='Always Open' → best_topic_id='OUT_OF_STOCK', best_topic_name='Out of Stock', similarity=0.3619
# [LOG][row 143] novel_label='Very basic experience' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4928
# [LOG][row 144] novel_label='Credit card activation issue' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.2760
# [LOG][row 145] novel_label='Order History Management' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.3494
# [LOG][row 146] novel_label='Famous Biryani Mention' → best_topic_id='NEGATIVE_GENERIC', best_topic_name='Negative Generic', similarity=0.1376
# [LOG][row 147] novel_label='Restaurant Communication Issue' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.4998
# [LOG][row 148] novel_label='Location Search Issue' → best_topic_id='CANT_FIND_ADDRESS', best_topic_name='Can't Find Address', similarity=0.4099
# [LOG][row 149] novel_label='Unclear feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3410
# [LOG][row 150] novel_label='Free items increase cooking time' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.3829
# [LOG][row 151] novel_label='Emotional expression' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2327
# [LOG][row 152] novel_label='Fraudulent Activity' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.3730
# [LOG][row 153] novel_label='Eatlist feature removal' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.3003
# [LOG][row 154] novel_label='No coupon for new users' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.2629
# [LOG][row 155] novel_label='Positive sentiment expressed' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4154
# [LOG][row 156] novel_label='HDFC bank application issues' → best_topic_id='PAYMENT_FAILURE', best_topic_name='Payment Failure', similarity=0.2575
# [LOG][row 157] novel_label='Request for more offers' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2982
# [LOG][row 158] novel_label='Positive feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.6613
# [LOG][row 159] novel_label='Inappropriate language' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.2959
# [LOG][row 160] novel_label='Severe dissatisfaction' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4615
# [LOG][row 161] novel_label='Positive Feedback on Combos' → best_topic_id='GOOD_QUALITY_FOOD', best_topic_name='Good Quality Food', similarity=0.4490
# [LOG][row 162] novel_label='GST Payment Concern' → best_topic_id='MONEY_ALREADY_EATEN', best_topic_name='Money Already Eaten', similarity=0.3268
# [LOG][row 163] novel_label='Easy Shopping Experience' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.3743
# [LOG][row 164] novel_label='Mood Stabilization via Food' → best_topic_id='GOOD_QUALITY_FOOD', best_topic_name='Good Quality Food', similarity=0.2279
# [LOG][row 165] novel_label='Time-saving food discovery' → best_topic_id='STALE_FOOD', best_topic_name='Stale Food', similarity=0.3945
# [LOG][row 166] novel_label='Delivery Request' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.5128
# [LOG][row 167] novel_label='Table reservation issue' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.4272
# [LOG][row 168] novel_label='Incomplete Review' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.2975
# [LOG][row 169] novel_label='Lack of faithfulness' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4347
# [LOG][row 170] novel_label='First Delivery Experience' → best_topic_id='FAST_DELIVERY', best_topic_name='Fast Delivery', similarity=0.4885
# [LOG][row 171] novel_label='Bad delivery experience' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.4995
# [LOG][row 172] novel_label='No Offer Available' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.3674
# [LOG][row 173] novel_label='More Payment Options Needed' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.3831
# [LOG][row 174] novel_label='Account-related issue' → best_topic_id='LOGIN_BUG', best_topic_name='Login Bug', similarity=0.4028
# [LOG][row 175] novel_label='Negative sentiment without specifics' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4870
# [LOG][row 176] novel_label='Fast Time Order' → best_topic_id='FAST_DELIVERY', best_topic_name='Fast Delivery', similarity=0.6333
# [LOG][row 177] novel_label='Unclear Experience Description' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3301
# [LOG][row 178] novel_label='Request for faster orders' → best_topic_id='FAST_DELIVERY', best_topic_name='Fast Delivery', similarity=0.4802
# [LOG][row 179] novel_label='Job creation through delivery apps' → best_topic_id='FAST_DELIVERY', best_topic_name='Fast Delivery', similarity=0.4242
# [LOG][row 180] novel_label='Delivery timing issue' → best_topic_id='LATE_DELIVERY', best_topic_name='Late Delivery', similarity=0.6502
# [LOG][row 181] novel_label='App issue' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5093
# [LOG][row 182] novel_label='Lesser Freebies' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3865
# [LOG][row 183] novel_label='Generic Positive Greeting' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5415
# [LOG][row 184] novel_label='Hygiene Issues' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.3103
# [LOG][row 185] novel_label='Unclear Service Quality' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4870
# [LOG][row 186] novel_label='Scarcity of partners' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.3824
# [LOG][row 187] novel_label='Generic Negative Feedback' → best_topic_id='NEGATIVE_GENERIC', best_topic_name='Negative Generic', similarity=0.6291
# [LOG][row 188] novel_label='Unclear Automated Calls' → best_topic_id='BOT_ONLY_NO_HUMAN', best_topic_name='Bot Only No Human Support', similarity=0.3253
# [LOG][row 189] novel_label='Cancellation fee concern' → best_topic_id='NO_CANCEL_OPTION', best_topic_name='No Cancel Option', similarity=0.3397
# [LOG][row 190] novel_label='Positive sentiment without issue' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4734
# [LOG][row 191] novel_label='UI Navigation Issue' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.3266
# [LOG][row 192] novel_label='Unclear Customer Scheme Feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4555
# [LOG][row 193] novel_label='Food not received' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.4906
# [LOG][row 194] novel_label='Defective Product Complaint' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.3020
# [LOG][row 195] novel_label='Address Addition Delay' → best_topic_id='CANT_FIND_ADDRESS', best_topic_name='Can't Find Address', similarity=0.3999
# [LOG][row 196] novel_label='Poor Customer Support' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4619
# [LOG][row 197] novel_label='No Coupons Available' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.2845
# [LOG][row 198] novel_label='Indeterminate Review' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.2661
# [LOG][row 199] novel_label='No facility issue' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.3329
# [LOG][row 200] novel_label='Generic Thank You' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5004
# [LOG][row 201] novel_label='Instamart unserviceable message' → best_topic_id='OUT_OF_STOCK', best_topic_name='Out of Stock', similarity=0.2941
# [LOG][row 202] novel_label='Negative feedback on app' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5915
# [LOG][row 203] novel_label='Poor service experience' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.6453
# [LOG][row 204] novel_label='Payment Interface Simplification' → best_topic_id='MONEY_ALREADY_EATEN', best_topic_name='Money Already Eaten', similarity=0.3157
# [LOG][row 205] novel_label='App dissatisfaction' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.6399
# [LOG][row 206] novel_label='Restaurant quality inspection' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.4256
# [LOG][row 207] novel_label='Difficulty in finding items' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.3111
# [LOG][row 208] novel_label='Positive food recommendation' → best_topic_id='GOOD_QUALITY_FOOD', best_topic_name='Good Quality Food', similarity=0.5696
# [LOG][row 209] novel_label='General delivery statement' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.5256
# [LOG][row 210] novel_label='Excessive Ads' → best_topic_id='HIGH_FEES', best_topic_name='High Fees', similarity=0.3400
# [LOG][row 211] novel_label='Payment Module Issues' → best_topic_id='PAYMENT_FAILURE', best_topic_name='Payment Failure', similarity=0.5106
# [LOG][row 212] novel_label='Timing Issue' → best_topic_id='NO_CANCEL_OPTION', best_topic_name='No Cancel Option', similarity=0.3846
# [LOG][row 213] novel_label='General mention of Swiggy' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2293
# [LOG][row 214] novel_label='Reward System Issue' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3391
# [LOG][row 215] novel_label='Fraudulent Partner Issue' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.3535
# [LOG][row 216] novel_label='App Trust Issues' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5616
# [LOG][row 217] novel_label='Unwanted Notifications' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2722
# [LOG][row 218] novel_label='Rate and offer issues' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.3440
# [LOG][row 219] novel_label='Open Packing Issue' → best_topic_id='PACKAGING_LEAK', best_topic_name='Packaging Leak', similarity=0.3292
# [LOG][row 220] novel_label='Health-related issue' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.2557
# [LOG][row 221] novel_label='Pricing Discrepancy' → best_topic_id='OVERPRICED_ITEMS', best_topic_name='Overpriced Items', similarity=0.4971
# [LOG][row 222] novel_label='Urgent request for assistance' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.3084
# [LOG][row 223] novel_label='Ambiguous Feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3856
# [LOG][row 224] novel_label='GST Charge Concern' → best_topic_id='HIGH_FEES', best_topic_name='High Fees', similarity=0.3645
# [LOG][row 225] novel_label='Instamart light issue' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.2573
# [LOG][row 226] novel_label='GPay cashback offer' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.2689
# [LOG][row 227] novel_label='Generic feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5209
# [LOG][row 228] novel_label='Installation Issue' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.2457
# [LOG][row 229] novel_label='Grocery Offers' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.3944
# [LOG][row 230] novel_label='Frequent Order Cancellations' → best_topic_id='NO_CANCEL_OPTION', best_topic_name='No Cancel Option', similarity=0.4114
# [LOG][row 231] novel_label='Low Prices' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.4664
# [LOG][row 232] novel_label='Vague feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4175
# [LOG][row 233] novel_label='Careless Delivery' → best_topic_id='RUDE_DELIVERY_PERSON', best_topic_name='Rude Delivery Person', similarity=0.5425
# [LOG][row 234] novel_label='Scammers and fraud concerns' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.2946
# [LOG][row 235] novel_label='Food quality issue' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.6856
# [LOG][row 236] novel_label='Cancellation Issue' → best_topic_id='NO_CANCEL_OPTION', best_topic_name='No Cancel Option', similarity=0.6449
# [LOG][row 237] novel_label='Refund Issue' → best_topic_id='REFUND_FRICTION', best_topic_name='Refund Friction', similarity=0.5261
# [LOG][row 238] novel_label='Delivery Timing Concern' → best_topic_id='LATE_DELIVERY', best_topic_name='Late Delivery', similarity=0.6311
# [LOG][row 239] novel_label='Delivery Partner Availability Issue' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.4390
# [LOG][row 240] novel_label='Minor Changes Required' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2328
# [LOG][row 241] novel_label='Affordable Pricing' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.4088
# [LOG][row 242] novel_label='Discount Feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4633
# [LOG][row 243] novel_label='Fasting Experience' → best_topic_id='FAST_DELIVERY', best_topic_name='Fast Delivery', similarity=0.3966
# [LOG][row 244] novel_label='Buyer safety concerns' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.3391
# [LOG][row 245] novel_label='Order Status Confusion' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.4230
# [LOG][row 246] novel_label='Unclear Item Source' → best_topic_id='WRONG_ITEM', best_topic_name='Wrong Item', similarity=0.5972
# [LOG][row 247] novel_label='Delivery Issues' → best_topic_id='RUDE_DELIVERY_PERSON', best_topic_name='Rude Delivery Person', similarity=0.4431
# [LOG][row 248] novel_label='Platform Improvement Suggestion' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3222
# [LOG][row 249] novel_label='Fake App Review' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5678
# [LOG][row 250] novel_label='Unclear Review Context' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.2637
# [LOG][row 251] novel_label='Emoticon Only Review' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3164
# [LOG][row 252] novel_label='Fake Offers' → best_topic_id='WRONG_ITEM', best_topic_name='Wrong Item', similarity=0.3456
# [LOG][row 253] novel_label='Order visibility issue' → best_topic_id='MONEY_ALREADY_EATEN', best_topic_name='Money Already Eaten', similarity=0.5340
# [LOG][row 254] novel_label='Incomplete offer details' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.5428
# [LOG][row 255] novel_label='Comment on laziness' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2715
# [LOG][row 256] novel_label='Delivery person lacks change' → best_topic_id='RUDE_DELIVERY_PERSON', best_topic_name='Rude Delivery Person', similarity=0.5371
# [LOG][row 257] novel_label='Class service issue' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5263
# [LOG][row 258] novel_label='Positive Food Experience' → best_topic_id='GOOD_QUALITY_FOOD', best_topic_name='Good Quality Food', similarity=0.6097
# [LOG][row 259] novel_label='App design issues' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.6476
# [LOG][row 260] novel_label='Missing logout option' → best_topic_id='NO_CANCEL_OPTION', best_topic_name='No Cancel Option', similarity=0.2874
# [LOG][row 261] novel_label='Supermarket Service' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.3610
# [LOG][row 262] novel_label='Poor Service Experience' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5714
# [LOG][row 263] novel_label='Cashback Feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4384
# [LOG][row 264] novel_label='Missing Offers' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.3806
# [LOG][row 265] novel_label='Juice request' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.2046
# [LOG][row 266] novel_label='Fraudulent Delivery Partner' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.5104
# [LOG][row 267] novel_label='Unspecified offer issue' → best_topic_id='OUT_OF_STOCK', best_topic_name='Out of Stock', similarity=0.3051
# [LOG][row 268] novel_label='Delivery Time Inquiry' → best_topic_id='LATE_DELIVERY', best_topic_name='Late Delivery', similarity=0.5128
# [LOG][row 269] novel_label='Request for low rating' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3319
# [LOG][row 270] novel_label='Offers not available' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.3899
# [LOG][row 271] novel_label='Restaurant Closed After Order' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.4153
# [LOG][row 272] novel_label='First-time experience inquiry' → best_topic_id='GOOD_QUALITY_FOOD', best_topic_name='Good Quality Food', similarity=0.4264
# [LOG][row 273] novel_label='User-friendly selection process' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.3401
# [LOG][row 274] novel_label='Deceptive Practices' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.4242
# [LOG][row 275] novel_label='Product quality issue' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.3027
# [LOG][row 276] novel_label='Service Quality Inquiry' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.6072
# [LOG][row 277] novel_label='No discount for first order' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.3631
# [LOG][row 278] novel_label='Delivery partner floor issue' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.5565
# [LOG][row 279] novel_label='Best Offers' → best_topic_id='OVERPRICED_ITEMS', best_topic_name='Overpriced Items', similarity=0.2780
# [LOG][row 280] novel_label='Ambiguous positive sentiment' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4357
# [LOG][row 281] novel_label='Delivery person asking for extra money' → best_topic_id='RUDE_DELIVERY_PERSON', best_topic_name='Rude Delivery Person', similarity=0.4586
# [LOG][row 282] novel_label='Unrelated Review Content' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.4280
# [LOG][row 283] novel_label='Operational Challenges' → best_topic_id='FAST_DELIVERY', best_topic_name='Fast Delivery', similarity=0.4440
# [LOG][row 284] novel_label='New launch feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3071
# [LOG][row 285] novel_label='Unclear review sentiment' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3077
# [LOG][row 286] novel_label='Lack of Member Benefits' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3334
# [LOG][row 287] novel_label='Positive feedback on food' → best_topic_id='GOOD_QUALITY_FOOD', best_topic_name='Good Quality Food', similarity=0.6656
# [LOG][row 288] novel_label='Negative app feature feedback' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5232
# [LOG][row 289] novel_label='Positive sentiment about elegance' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3594
# [LOG][row 290] novel_label='Scam and manipulation' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5150
# [LOG][row 291] novel_label='High rate concern' → best_topic_id='HIGH_FEES', best_topic_name='High Fees', similarity=0.3543
# [LOG][row 292] novel_label='Customer offers feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5511
# [LOG][row 293] novel_label='Slow Service' → best_topic_id='FAST_DELIVERY', best_topic_name='Fast Delivery', similarity=0.3960
# [LOG][row 294] novel_label='Ambiguous rating' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2738
# [LOG][row 295] novel_label='Slow Delivery' → best_topic_id='FAST_DELIVERY', best_topic_name='Fast Delivery', similarity=0.6936
# [LOG][row 296] novel_label='Cash off promotion' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.3585
# [LOG][row 297] novel_label='Request for Offers' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.3099
# [LOG][row 298] novel_label='Generic positive sentiment' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4793
# [LOG][row 299] novel_label='Missing offers' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.3628
# [LOG][row 300] novel_label='Positive feedback on maintenance' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5515
# [LOG][row 301] novel_label='Fraudulent Behavior' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.4041
# [LOG][row 302] novel_label='Emoticon Review' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2600
# [LOG][row 303] novel_label='Single word review' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.2229
# [LOG][row 304] novel_label='Cultural Sensitivity Issues' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.3623
# [LOG][row 305] novel_label='Mildly Positive Feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.6047
# [LOG][row 306] novel_label='Preferred food nearby' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.5066
# [LOG][row 307] novel_label='Location Mentioned' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.4439
# [LOG][row 308] novel_label='Map Accuracy Issue' → best_topic_id='CANT_FIND_ADDRESS', best_topic_name='Can't Find Address', similarity=0.4520
# [LOG][row 309] novel_label='Low Price Concern' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.7082
# [LOG][row 310] novel_label='Delivery charge issue' → best_topic_id='HIGH_FEES', best_topic_name='High Fees', similarity=0.5508
# [LOG][row 311] novel_label='Location Delivery Issue' → best_topic_id='CANT_FIND_ADDRESS', best_topic_name='Can't Find Address', similarity=0.5917
# [LOG][row 312] novel_label='Cashback issue with payment' → best_topic_id='MONEY_ALREADY_EATEN', best_topic_name='Money Already Eaten', similarity=0.4376
# [LOG][row 313] novel_label='Feedback and payment issues' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4944
# [LOG][row 314] novel_label='GST Rate Concern' → best_topic_id='HIGH_FEES', best_topic_name='High Fees', similarity=0.2997
# [LOG][row 315] novel_label='User input disregard' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5340
# [LOG][row 316] novel_label='App Bug Issues' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.4395
# [LOG][row 317] novel_label='Distance Discrepancy Issue' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.3376
# [LOG][row 318] novel_label='Negative sentiment towards service' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.6534
# [LOG][row 319] novel_label='Order Grouping Confusion' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.3887
# [LOG][row 320] novel_label='Ads irritation for premium users' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2408
# [LOG][row 321] novel_label='Positive Offers Feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5836
# [LOG][row 322] novel_label='Limited Offers Compared to Competitor' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.3092
# [LOG][row 323] novel_label='No return policy for appliances' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.3274
# [LOG][row 324] novel_label='General complaint' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4330
# [LOG][row 325] novel_label='Search Functionality Issue' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.3866
# [LOG][row 326] novel_label='Free item promotion' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3017
# [LOG][row 327] novel_label='High charges for food' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.5394
# [LOG][row 328] novel_label='Good offers and shopping' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3786
# [LOG][row 329] novel_label='Chained Supply' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.2296
# [LOG][row 330] novel_label='Weather-related delay' → best_topic_id='LATE_DELIVERY', best_topic_name='Late Delivery', similarity=0.3991
# [LOG][row 331] novel_label='Missing Buy Option' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.2824
# [LOG][row 332] novel_label='Positive Feedback on Pictures' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5136
# [LOG][row 333] novel_label='Minimal context provided' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.2684
# [LOG][row 334] novel_label='Ambiguous feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4986
# ...
# [LOG][row 942] novel_label='Pricing Inquiry' → best_topic_id='OVERPRICED_ITEMS', best_topic_name='Overpriced Items', similarity=0.4625
# [LOG][row 943] novel_label='Incomplete order feedback' → best_topic_id='MONEY_ALREADY_EATEN', best_topic_name='Money Already Eaten', similarity=0.3935
# [LOG][row 944] novel_label='Speed of pizza delivery' → best_topic_id='FAST_DELIVERY', best_topic_name='Fast Delivery', similarity=0.5282
# [LOG][row 945] novel_label='Generic gratitude' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4927
# [LOG][row 946] novel_label='Cultural Sensitivity Issue' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.2877
# [LOG][row 947] novel_label='Company Greed' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.3216
# [LOG][row 948] novel_label='Fake coupon code issue' → best_topic_id='WRONG_ITEM', best_topic_name='Wrong Item', similarity=0.3090
# [LOG][row 949] novel_label='Train delivery hygiene concerns' → best_topic_id='PACKAGING_LEAK', best_topic_name='Packaging Leak', similarity=0.3305
# [LOG][row 950] novel_label='Rain fee charge issue' → best_topic_id='HIGH_FEES', best_topic_name='High Fees', similarity=0.3613
# [LOG][row 951] novel_label='Missing promotional offer' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.3388
# [LOG][row 952] novel_label='Service Availability Concern' → best_topic_id='OUT_OF_STOCK', best_topic_name='Out of Stock', similarity=0.2646
# [LOG][row 953] novel_label='Emotional Reaction' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3076
# [LOG][row 954] novel_label='Not tried yet' → best_topic_id='VERY_GOOD_SERVICE', best_topic_name='Very Good Service', similarity=0.4925
# [LOG][row 955] novel_label='Order Cancellation Inquiry' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.5028
# [LOG][row 956] novel_label='Best service feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.7531
# [LOG][row 957] novel_label='Ambiguous Review Content' → best_topic_id='WRONG_ITEM', best_topic_name='Wrong Item', similarity=0.2302
# [LOG][row 958] novel_label='Credit Card Brand Collaboration' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2073
# [LOG][row 959] novel_label='Membership Renewal Issue' → best_topic_id='LOGIN_BUG', best_topic_name='Login Bug', similarity=0.3264
# [LOG][row 960] novel_label='Extreme Rating Request' → best_topic_id='NEGATIVE_GENERIC', best_topic_name='Negative Generic', similarity=0.3598
# [LOG][row 961] novel_label='Address Issues' → best_topic_id='CANT_FIND_ADDRESS', best_topic_name='Can't Find Address', similarity=0.2989
# [LOG][row 962] novel_label='Unsolicited Calls Issue' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.3670
# [LOG][row 963] novel_label='Concerns about pricing transparency' → best_topic_id='HIGH_FEES', best_topic_name='High Fees', similarity=0.4931
# [LOG][row 964] novel_label='Rating Change Issue' → best_topic_id='WRONG_ITEM', best_topic_name='Wrong Item', similarity=0.2488
# [LOG][row 965] novel_label='App Crashes and Bugs' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5056
# [LOG][row 966] novel_label='Unfulfilled Promises' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.2906
# [LOG][row 967] novel_label='Order Cancellation Concern' → best_topic_id='NO_CANCEL_OPTION', best_topic_name='No Cancel Option', similarity=0.5473
# [LOG][row 968] novel_label='Comparison with Zomato' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.2380
# [LOG][row 969] novel_label='Generic comment' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4998
# [LOG][row 970] novel_label='Referral Code Issue' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.2477
# [LOG][row 971] novel_label='Payment Method Suggestion' → best_topic_id='PAYMENT_FAILURE', best_topic_name='Payment Failure', similarity=0.4136
# [LOG][row 972] novel_label='Outstanding grocery app service' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5226
# [LOG][row 973] novel_label='Trust Issues with Platform' → best_topic_id='HIGH_FEES', best_topic_name='High Fees', similarity=0.3024
# [LOG][row 974] novel_label='Poor business ethics' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.4678
# [LOG][row 975] novel_label='Discount not applying' → best_topic_id='MONEY_ALREADY_EATEN', best_topic_name='Money Already Eaten', similarity=0.4287
# [LOG][row 976] novel_label='Exercise Mentioned' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.2222
# [LOG][row 977] novel_label='Best Deal Feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.4936
# [LOG][row 978] novel_label='Price Benefits' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.3553
# [LOG][row 979] novel_label='Diya event disabled' → best_topic_id='CART_BUG', best_topic_name='Cart Bug', similarity=0.2271
# [LOG][row 980] novel_label='Missing Eatlist Feature' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.3325
# [LOG][row 981] novel_label='Free treat issue' → best_topic_id='NEGATIVE_GENERIC', best_topic_name='Negative Generic', similarity=0.2777
# [LOG][row 982] novel_label='No first order offers' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.3808
# [LOG][row 983] novel_label='Customer service issue' → best_topic_id='NO_RESPONSE_COMPLAINT', best_topic_name='No Response to Complaint', similarity=0.3742
# [LOG][row 984] novel_label='Comparison with Competitor' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.2481
# [LOG][row 985] novel_label='App Uninstallation' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.3608
# [LOG][row 986] novel_label='Order Rejection Issue' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.4630
# [LOG][row 987] novel_label='Free Pizza Offer Issue' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.3829
# [LOG][row 988] novel_label='Coupon Removal Issue' → best_topic_id='MONEY_ALREADY_EATEN', best_topic_name='Money Already Eaten', similarity=0.2999
# [LOG][row 989] novel_label='Poor experience with amount' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.4011
# [LOG][row 990] novel_label='Unclear offer details' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.2757
# [LOG][row 991] novel_label='Food taste issue' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.4678
# [LOG][row 992] novel_label='Promotions and Offers' → best_topic_id='SURGE_PRICING', best_topic_name='Surge Pricing', similarity=0.3151
# [LOG][row 993] novel_label='Scammers' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.3405
# [LOG][row 994] novel_label='Order Modification Issue' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.3973
# [LOG][row 995] novel_label='Cheating Allegation' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.4300
# [LOG][row 996] novel_label='Strong server taste' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3659
# [LOG][row 997] novel_label='Offers and Promotions' → best_topic_id='OUT_OF_STOCK', best_topic_name='Out of Stock', similarity=0.3219
# [LOG][row 998] novel_label='App Wastage Issue' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.3798
# [LOG][row 999] novel_label='General complaint about service' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5960
# [LOG][row 1000] novel_label='Positive feedback on coupons' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5255
# [LOG][row 1001] novel_label='Excited about offers' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3459
# [LOG][row 1002] novel_label='NonVeg and Veg preparation concern' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.2060
# [LOG][row 1003] novel_label='Multi cart option suggestion' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.3657
# [LOG][row 1004] novel_label='Positive Delivery Experience' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.5856
# [LOG][row 1005] novel_label='Extreme dissatisfaction' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3868
# [LOG][row 1006] novel_label='Spelling Error' → best_topic_id='COD_NOT_AVAILABLE', best_topic_name='COD Not Available', similarity=0.2646
# [LOG][row 1007] novel_label='Positive sentiment without context' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3947
# [LOG][row 1008] novel_label='User name only review' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2367
# [LOG][row 1009] novel_label='Offer Feedback' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3625
# [LOG][row 1010] novel_label='Descriptive food comment' → best_topic_id='GOOD_QUALITY_FOOD', best_topic_name='Good Quality Food', similarity=0.3698
# [LOG][row 1011] novel_label='General complaint about food' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.5258
# [LOG][row 1012] novel_label='Unclear feedback on app' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5974
# [LOG][row 1013] novel_label='Disappointing Coupons' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3404
# [LOG][row 1014] novel_label='Excessive Emojis' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.2166
# [LOG][row 1015] novel_label='Restaurant Blocking Issue' → best_topic_id='LIMITED_OPTIONS', best_topic_name='Limited Options', similarity=0.5345
# [LOG][row 1016] novel_label='Service quality issue' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3745
# [LOG][row 1017] novel_label='Offer Retraction Issue' → best_topic_id='REFUND_FRICTION', best_topic_name='Refund Friction', similarity=0.4124
# [LOG][row 1018] novel_label='Friendship and happiness message' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3505
# [LOG][row 1019] novel_label='Unclear Issue' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.4321
# [LOG][row 1020] novel_label='Confusing Ordering Options' → best_topic_id='ORDER_INCOMPLETE', best_topic_name='Order Incomplete', similarity=0.3588
# [LOG][row 1021] novel_label='Underrated restaurants issue' → best_topic_id='UNPROFESSIONAL', best_topic_name='Unprofessional Behavior', similarity=0.4730
# [LOG][row 1022] novel_label='Cashback Confusion' → best_topic_id='REFUND_FRICTION', best_topic_name='Refund Friction', similarity=0.3526
# [LOG][row 1023] novel_label='Unclear review content' → best_topic_id='POSITIVE_EXPERIENCE', best_topic_name='Positive Experience', similarity=0.3184
# [LOG][row 1024] novel_label='GST Concerns' → best_topic_id='HIGH_FEES', best_topic_name='High Fees', similarity=0.4269
# [LOG][row 1025] novel_label='Negative App Experience' → best_topic_id='GREAT_APP', best_topic_name='Great App', similarity=0.5917
# [LOG][row 1026] novel_label='Delivery Rating Issue' → best_topic_id='NO_DELIVERY_YET', best_topic_name='No Delivery Yet', similarity=0.4613
# [LOG][row 1027] novel_label='Filter preferences request' → best_topic_id='POOR_QUALITY', best_topic_name='Poor Quality', similarity=0.3808
# [LOG] Built 1028 candidate matches
# ✓ Candidate matches computed (1028 rows)
# shape: (10, 6)
# ┌─────────────────┬────────────────┬────────────────┬────────────────┬────────────────┬────────────┐
# │ novel_label     ┆ novel_rational ┆ first_seen     ┆ best_topic_id  ┆ best_topic_nam ┆ similarity │
# │ ---             ┆ e              ┆ ---            ┆ ---            ┆ e              ┆ ---        │
# │ str             ┆ ---            ┆ datetime[μs,   ┆ str            ┆ ---            ┆ f64        │
# │                 ┆ str            ┆ Asia/Kolkata]  ┆                ┆ str            ┆            │
# ╞═════════════════╪════════════════╪════════════════╪════════════════╪════════════════╪════════════╡
# │ Positive        ┆ The review     ┆ 2025-10-04     ┆ POSITIVE_EXPER ┆ Positive       ┆ 0.840523   │
# │ service         ┆ expresses      ┆ 16:13:01 IST   ┆ IENCE          ┆ Experience     ┆            │
# │ feedback        ┆ satisfact…     ┆                ┆                ┆                ┆            │
# │ Generic         ┆ The review     ┆ 2025-09-28     ┆ POSITIVE_EXPER ┆ Positive       ┆ 0.827888   │
# │ positive        ┆ expresses a    ┆ 05:16:42 IST   ┆ IENCE          ┆ Experience     ┆            │
# │ feedback        ┆ positiv…       ┆                ┆                ┆                ┆            │
# │ Best service    ┆ The review     ┆ 2025-10-20     ┆ POSITIVE_EXPER ┆ Positive       ┆ 0.753112   │
# │ feedback        ┆ expresses a    ┆ 04:11:57 IST   ┆ IENCE          ┆ Experience     ┆            │
# │                 ┆ positiv…       ┆                ┆                ┆                ┆            │
# │ Delivery Speed  ┆ The review     ┆ 2025-10-15     ┆ FAST_DELIVERY  ┆ Fast Delivery  ┆ 0.730695   │
# │ Concern         ┆ expresses      ┆ 09:30:44 IST   ┆                ┆                ┆            │
# │                 ┆ dissatisf…     ┆                ┆                ┆                ┆            │
# │ Positive        ┆ The review     ┆ 2025-10-04     ┆ POSITIVE_EXPER ┆ Positive       ┆ 0.724916   │
# │ feedback about  ┆ expresses a    ┆ 16:00:59 IST   ┆ IENCE          ┆ Experience     ┆            │
# │ servic…         ┆ positiv…       ┆                ┆                ┆                ┆            │
# │ Order not       ┆ The review     ┆ 2025-10-18     ┆ NO_DELIVERY_YE ┆ No Delivery    ┆ 0.712767   │
# │ received        ┆ indicates      ┆ 16:13:18 IST   ┆ T              ┆ Yet            ┆            │
# │                 ┆ waiting f…     ┆                ┆                ┆                ┆            │
# │ Low Price       ┆ The review     ┆ 2025-09-30     ┆ POOR_QUALITY   ┆ Poor Quality   ┆ 0.708216   │
# │ Concern         ┆ mentions low   ┆ 16:34:57 IST   ┆                ┆                ┆            │
# │                 ┆ price …        ┆                ┆                ┆                ┆            │
# │ Generic         ┆ The review     ┆ 2025-09-28     ┆ POSITIVE_EXPER ┆ Positive       ┆ 0.69851    │
# │ Positive        ┆ expresses a    ┆ 07:02:46 IST   ┆ IENCE          ┆ Experience     ┆            │
# │ Feedback        ┆ positiv…       ┆                ┆                ┆                ┆            │
# │ Slow Delivery   ┆ The review     ┆ 2025-10-22     ┆ FAST_DELIVERY  ┆ Fast Delivery  ┆ 0.6936     │
# │                 ┆ indicates a    ┆ 14:19:24 IST   ┆                ┆                ┆            │
# │                 ┆ delay w…       ┆                ┆                ┆                ┆            │
# │ App feedback    ┆ The review     ┆ 2025-10-21     ┆ GREAT_APP      ┆ Great App      ┆ 0.690503   │
# │                 ┆ provides       ┆ 20:13:31 IST   ┆                ┆                ┆            │
# │                 ┆ generic fe…    ┆                ┆                ┆                ┆            │
# └─────────────────┴────────────────┴────────────────┴────────────────┴────────────────┴────────────┘

# %% [markdown]
# ## Resolve Ambiguous Candidates with LLM

# %%
import time

for size in [5, 10, 20, 50, 100]:
    start = time.time()
    llm.batch_complete(prompts[:size], batch_size=size)
    print(f"Batch {size}: {time.time()-start:.2f}s")
# Out:
# Processing: 100%|█████████████████████████████████| 1/1 [00:00<00:00,  3.97it/s]
# Batch 5: 0.25s
# Processing: 100%|█████████████████████████████████| 1/1 [00:00<00:00,  1.99it/s]
# Batch 10: 0.50s
# Processing: 100%|█████████████████████████████████| 1/1 [00:01<00:00,  1.01s/it]
# Batch 20: 1.01s
# Processing: 100%|█████████████████████████████████| 1/1 [00:02<00:00,  2.51s/it]
# Batch 50: 2.51s
# Processing: 100%|█████████████████████████████████| 1/1 [00:41<00:00, 41.02s/it]
# Batch 100: 41.02s

# %%
import concurrent.futures
import polars as pl
import time

llm = LLMClient(provider=LLM_PROVIDER, model=LLM_MODEL)
print(f"✓ Ready LLM adjudicator ({LLM_PROVIDER}/{LLM_MODEL})")

actions, prompts = [], []

# Build prompt list
for row in candidate_df.iter_rows(named=True):
    if row['similarity'] >= SIM_THRESHOLD:
        actions.append({**row, 'action': 'merge', 'notes': 'auto-merge via embedding score'})
    else:
        prompts.append({
            'system_prompt': 'You are a taxonomy expert consolidating duplicate topics. Only reply with strict JSON.',
            'user_prompt': f"""Topic A: {row['novel_label']} ({row['novel_rationale']})
Topic B: {row['best_topic_name']}
Return JSON: {{"action":"merge|new","label":"<final>","notes":"<reason>"}}""",
            'temperature': 0.0,
            'response_format': 'json'
        })

# Function to handle one batch safely
def process_batch(batch, batch_id):
    try:
        start = time.time()
        result = llm.batch_complete(batch, batch_size=10)
        print(f"✓ Batch {batch_id} done in {time.time() - start:.2f}s ({len(batch)} prompts)")
        return result
    except Exception as e:
        print(f"⚠️ Batch {batch_id} failed: {e}")
        return [None] * len(batch)

# Run batches in parallel
responses = []
if prompts:
    batches = [prompts[i:i+10] for i in range(0, len(prompts), 10)]
    print(f"🚀 Total batches: {len(batches)} (running with max_workers=20)")

    start = time.time()
    with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
        future_to_id = {executor.submit(process_batch, b, i+1): i+1 for i, b in enumerate(batches)}
        for future in concurrent.futures.as_completed(future_to_id):
            batch_id = future_to_id[future]
            try:
                res = future.result()
                if res:
                    responses.extend(res)
            except Exception as e:
                print(f"⚠️ Batch {batch_id} error: {e}")
    print(f"✅ All batches completed in {time.time() - start:.2f}s")
else:
    responses = []

# Merge responses back to dataframe
for resp, row in zip(
    responses,
    (r for r in candidate_df.iter_rows(named=True) if r['similarity'] < SIM_THRESHOLD)
):
    if resp is None:
        actions.append({**row, 'action': 'review', 'notes': 'LLM response missing'})
        continue
    actions.append({
        **row,
        'action': resp.get('action', 'review'),
        'notes': resp.get('notes'),
        'llm_label': resp.get('label')
    })

actions_df = pl.DataFrame(actions)
print(f"✓ Proposed actions: {actions_df.height} rows")
try:
    display(actions_df.head(10))
except NameError:
    print(actions_df.head(10))
# Out:
# ✓ Initialized megallm client with model gpt-4o-mini
# ✓ Ready LLM adjudicator (megallm/gpt-4o-mini)
# 🚀 Total batches: 103 (running with max_workers=20)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:27<00:00, 27.25s/it]
# ✓ Batch 2 done in 27.25s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:32<00:00, 32.82s/it]
# ✓ Batch 19 done in 32.87s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:34<00:00, 34.29s/it]
# ✓ Batch 3 done in 34.30s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:35<00:00, 35.44s/it]
# ✓ Batch 15 done in 35.47s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:35<00:00, 35.73s/it]
# ✓ Batch 9 done in 35.77s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:36<00:00, 36.62s/it]
# ✓ Batch 20 done in 36.66s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:36<00:00, 36.78s/it]
# ✓ Batch 14 done in 36.82s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Processing: 100%|█████████████████████████████████| 1/1 [00:37<00:00, 37.10s/it]
# ✓ Batch 1 done in 37.10s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:37<00:00, 37.16s/it]
# ✓ Batch 7 done in 37.18s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:37<00:00, 37.30s/it]
# ✓ Batch 6 done in 37.33s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:38<00:00, 38.35s/it]
# ✓ Batch 12 done in 38.39s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:38<00:00, 38.83s/it]
# ✓ Batch 5 done in 38.85s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:40<00:00, 40.01s/it]
# ✓ Batch 13 done in 40.04s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:40<00:00, 40.53s/it]
# ✓ Batch 17 done in 40.57s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:40<00:00, 40.59s/it]
# ✓ Batch 8 done in 40.63s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:41<00:00, 41.00s/it]
# ✓ Batch 10 done in 41.03s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:42<00:00, 42.24s/it]
# ✓ Batch 18 done in 42.28s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:44<00:00, 44.02s/it]
# ✓ Batch 4 done in 44.03s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:45<00:00, 45.12s/it]
# ✓ Batch 11 done in 45.15s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Error processing prompt: the JSON object must be str, bytes or bytearray, not NoneType
# Processing: 100%|█████████████████████████████████| 1/1 [00:47<00:00, 47.27s/it]
# ✓ Batch 16 done in 47.31s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:24<00:00, 24.17s/it]
# ✓ Batch 22 done in 24.18s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:22<00:00, 22.30s/it]
# ✓ Batch 29 done in 22.31s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:24<00:00, 24.57s/it]
# ✓ Batch 26 done in 24.57s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:26<00:00, 26.26s/it]
# ✓ Batch 24 done in 26.26s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:34<00:00, 34.60s/it]
# ✓ Batch 21 done in 34.60s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:25<00:00, 25.74s/it]
# ✓ Batch 30 done in 25.74s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:28<00:00, 28.79s/it]
# ✓ Batch 25 done in 28.79s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:26<00:00, 26.39s/it]
# ✓ Batch 31 done in 26.39s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:28<00:00, 28.44s/it]
# ✓ Batch 27 done in 28.44s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:27<00:00, 27.30s/it]
# ✓ Batch 32 done in 27.30s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Processing: 100%|█████████████████████████████████| 1/1 [00:29<00:00, 29.50s/it]
# ✓ Batch 28 done in 29.50s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:27<00:00, 27.74s/it]
# ✓ Batch 34 done in 27.74s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:35<00:00, 35.04s/it]
# ✓ Batch 23 done in 35.04s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:27<00:00, 27.46s/it]
# ✓ Batch 37 done in 27.46s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:30<00:00, 30.15s/it]
# ✓ Batch 35 done in 30.16s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:30<00:00, 30.52s/it]
# ✓ Batch 36 done in 30.53s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:28<00:00, 28.36s/it]
# ✓ Batch 38 done in 28.36s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:25<00:00, 25.24s/it]
# ✓ Batch 40 done in 25.24s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:27<00:00, 27.62s/it]
# ✓ Batch 39 done in 27.62s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:33<00:00, 33.83s/it]
# ✓ Batch 33 done in 33.83s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:25<00:00, 25.81s/it]
# ✓ Batch 45 done in 25.81s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:31<00:00, 31.85s/it]
# ✓ Batch 41 done in 31.85s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:24<00:00, 24.28s/it]
# ✓ Batch 49 done in 24.28s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:26<00:00, 26.20s/it]
# ✓ Batch 48 done in 26.20s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:32<00:00, 32.35s/it]
# ✓ Batch 42 done in 32.35s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:31<00:00, 31.06s/it]
# ✓ Batch 43 done in 31.06s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:31<00:00, 31.92s/it]
# ✓ Batch 44 done in 31.92s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:28<00:00, 28.72s/it]
# ✓ Batch 53 done in 28.72s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:27<00:00, 27.47s/it]
# ✓ Batch 55 done in 27.47s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:29<00:00, 29.50s/it]
# ✓ Batch 54 done in 29.50s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:37<00:00, 37.08s/it]
# ✓ Batch 46 done in 37.09s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:36<00:00, 36.15s/it]
# ✓ Batch 47 done in 36.16s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Processing: 100%|█████████████████████████████████| 1/1 [00:34<00:00, 34.41s/it]
# ✓ Batch 51 done in 34.41s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:29<00:00, 29.09s/it]
# ✓ Batch 58 done in 29.09s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:38<00:00, 38.03s/it]
# ✓ Batch 50 done in 38.03s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:30<00:00, 30.67s/it]
# ✓ Batch 60 done in 30.67s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:33<00:00, 33.04s/it]
# ✓ Batch 56 done in 33.04s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:34<00:00, 34.05s/it]
# ✓ Batch 59 done in 34.05s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:41<00:00, 41.14s/it]
# ✓ Batch 52 done in 41.14s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:41<00:00, 41.53s/it]
# ✓ Batch 57 done in 41.53s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:26<00:00, 26.23s/it]
# ✓ Batch 63 done in 26.24s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:20<00:00, 20.28s/it]
# ✓ Batch 68 done in 20.28s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:32<00:00, 32.71s/it]
# ✓ Batch 61 done in 32.71s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:29<00:00, 29.35s/it]
# ✓ Batch 65 done in 29.36s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:30<00:00, 30.38s/it]
# ✓ Batch 64 done in 30.38s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:22<00:00, 22.64s/it]
# ✓ Batch 70 done in 22.64s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:34<00:00, 34.88s/it]
# ✓ Batch 62 done in 34.89s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Processing: 100%|█████████████████████████████████| 1/1 [00:23<00:00, 23.80s/it]
# ✓ Batch 73 done in 23.81s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:24<00:00, 24.86s/it]
# ✓ Batch 74 done in 24.86s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:22<00:00, 22.45s/it]
# ✓ Batch 75 done in 22.45s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:28<00:00, 28.47s/it]
# ✓ Batch 69 done in 28.47s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:25<00:00, 25.26s/it]
# ✓ Batch 76 done in 25.26s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:30<00:00, 30.74s/it]
# ✓ Batch 71 done in 30.74s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:24<00:00, 24.73s/it]
# ✓ Batch 78 done in 24.73s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:43<00:00, 43.18s/it]
# ✓ Batch 66 done in 43.18s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:42<00:00, 42.80s/it]
# ✓ Batch 67 done in 42.81s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:41<00:00, 41.82s/it]
# ✓ Batch 72 done in 41.83s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:25<00:00, 25.98s/it]
# ✓ Batch 82 done in 25.98s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:28<00:00, 28.70s/it]
# ✓ Batch 81 done in 28.70s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:24<00:00, 24.54s/it]
# ✓ Batch 83 done in 24.54s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:21<00:00, 21.31s/it]
# ✓ Batch 87 done in 21.32s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:39<00:00, 39.32s/it]
# ✓ Batch 79 done in 39.32s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:35<00:00, 35.77s/it]
# ✓ Batch 80 done in 35.78s (10 prompts)
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:28<00:00, 28.49s/it]
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:25<00:00, 25.75s/it]
# ✓ Batch 86 done in 28.49s (10 prompts)
# ✓ Batch 88 done in 25.75s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:29<00:00, 29.42s/it]
# ✓ Batch 85 done in 29.42s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:29<00:00, 29.83s/it]
# ✓ Batch 84 done in 29.83s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:26<00:00, 26.33s/it]
# ✓ Batch 91 done in 26.33s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:27<00:00, 27.18s/it]
# ✓ Batch 90 done in 27.18s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:50<00:00, 50.10s/it]
# ✓ Batch 77 done in 50.10s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:28<00:00, 28.29s/it]
# ✓ Batch 93 done in 28.30s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:34<00:00, 34.49s/it]
#
#
#
#
#
#
#
#
#
#
# Processing: 100%|█████████████████████████████████| 1/1 [00:29<00:00, 29.60s/it]
# ✓ Batch 89 done in 34.49s (10 prompts)
# ✓ Batch 94 done in 29.60s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:31<00:00, 31.56s/it]
# ✓ Batch 92 done in 31.56s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:25<00:00, 25.92s/it]
# ✓ Batch 96 done in 25.93s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:13<00:00, 13.96s/it]
# ✓ Batch 103 done in 13.96s (6 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:28<00:00, 28.79s/it]
# ✓ Batch 95 done in 28.79s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:23<00:00, 23.43s/it]
# ✓ Batch 97 done in 23.43s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:22<00:00, 22.61s/it]
# ✓ Batch 98 done in 22.61s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:22<00:00, 22.15s/it]
# ✓ Batch 102 done in 22.16s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:27<00:00, 27.65s/it]
# ✓ Batch 100 done in 27.66s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:30<00:00, 30.14s/it]
# ✓ Batch 99 done in 30.14s (10 prompts)
# Processing: 100%|█████████████████████████████████| 1/1 [00:33<00:00, 33.44s/it]
# ✓ Batch 101 done in 33.44s (10 prompts)
# ✅ All batches completed in 178.55s
# ✓ Proposed actions: 1028 rows
# shape: (10, 9)
# ┌────────────┬────────────┬───────────┬───────────┬───┬───────────┬────────┬───────────┬───────────┐
# │ novel_labe ┆ novel_rati ┆ first_see ┆ best_topi ┆ … ┆ similarit ┆ action ┆ notes     ┆ llm_label │
# │ l          ┆ onale      ┆ n         ┆ c_id      ┆   ┆ y         ┆ ---    ┆ ---       ┆ ---       │
# │ ---        ┆ ---        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ str    ┆ str       ┆ str       │
# │ str        ┆ str        ┆ datetime[ ┆ str       ┆   ┆ f64       ┆        ┆           ┆           │
# │            ┆            ┆ μs, Asia/ ┆           ┆   ┆           ┆        ┆           ┆           │
# │            ┆            ┆ Kolkata]  ┆           ┆   ┆           ┆        ┆           ┆           │
# ╞════════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪════════╪═══════════╪═══════════╡
# │ Positive   ┆ The review ┆ 2025-10-0 ┆ POSITIVE_ ┆ … ┆ 0.840523  ┆ merge  ┆ auto-merg ┆ null      │
# │ service    ┆ expresses  ┆ 4         ┆ EXPERIENC ┆   ┆           ┆        ┆ e via     ┆           │
# │ feedback   ┆ satisfact… ┆ 16:13:01  ┆ E         ┆   ┆           ┆        ┆ embedding ┆           │
# │            ┆            ┆ IST       ┆           ┆   ┆           ┆        ┆ score     ┆           │
# │ Generic    ┆ The review ┆ 2025-09-2 ┆ POSITIVE_ ┆ … ┆ 0.827888  ┆ merge  ┆ auto-merg ┆ null      │
# │ positive   ┆ expresses  ┆ 8         ┆ EXPERIENC ┆   ┆           ┆        ┆ e via     ┆           │
# │ feedback   ┆ a positiv… ┆ 05:16:42  ┆ E         ┆   ┆           ┆        ┆ embedding ┆           │
# │            ┆            ┆ IST       ┆           ┆   ┆           ┆        ┆ score     ┆           │
# │ Best       ┆ The review ┆ 2025-10-2 ┆ POSITIVE_ ┆ … ┆ 0.753112  ┆ merge  ┆ Both      ┆ General   │
# │ service    ┆ expresses  ┆ 0         ┆ EXPERIENC ┆   ┆           ┆        ┆ topics    ┆ Positive  │
# │ feedback   ┆ a positiv… ┆ 04:11:57  ┆ E         ┆   ┆           ┆        ┆ express   ┆ Feedback  │
# │            ┆            ┆ IST       ┆           ┆   ┆           ┆        ┆ positive  ┆           │
# │            ┆            ┆           ┆           ┆   ┆           ┆        ┆ s…        ┆           │
# │ Delivery   ┆ The review ┆ 2025-10-1 ┆ FAST_DELI ┆ … ┆ 0.730695  ┆ merge  ┆ Consolida ┆ Service   │
# │ Speed      ┆ expresses  ┆ 5         ┆ VERY      ┆   ┆           ┆        ┆ ted       ┆ Feedback  │
# │ Concern    ┆ dissatisf… ┆ 09:30:44  ┆           ┆   ┆           ┆        ┆ feedback  ┆           │
# │            ┆            ┆ IST       ┆           ┆   ┆           ┆        ┆ related … ┆           │
# │ Positive   ┆ The review ┆ 2025-10-0 ┆ POSITIVE_ ┆ … ┆ 0.724916  ┆ merge  ┆ Both      ┆ Food      │
# │ feedback   ┆ expresses  ┆ 4         ┆ EXPERIENC ┆   ┆           ┆        ┆ topics    ┆ Quality   │
# │ about      ┆ a positiv… ┆ 16:00:59  ┆ E         ┆   ┆           ┆        ┆ address   ┆           │
# │ servic…    ┆            ┆ IST       ┆           ┆   ┆           ┆        ┆ aspects   ┆           │
# │            ┆            ┆           ┆           ┆   ┆           ┆        ┆ of…       ┆           │
# │ Order not  ┆ The review ┆ 2025-10-1 ┆ NO_DELIVE ┆ … ┆ 0.712767  ┆ merge  ┆ Both      ┆ Positive  │
# │ received   ┆ indicates  ┆ 8         ┆ RY_YET    ┆   ┆           ┆        ┆ topics    ┆ Feedback  │
# │            ┆ waiting f… ┆ 16:13:18  ┆           ┆   ┆           ┆        ┆ express a ┆ on Food   │
# │            ┆            ┆ IST       ┆           ┆   ┆           ┆        ┆ positive… ┆ Qual…     │
# │ Low Price  ┆ The review ┆ 2025-09-3 ┆ POOR_QUAL ┆ … ┆ 0.708216  ┆ new    ┆ This      ┆ Positive  │
# │ Concern    ┆ mentions   ┆ 0         ┆ ITY       ┆   ┆           ┆        ┆ topic hig ┆ Offers    │
# │            ┆ low price  ┆ 16:34:57  ┆           ┆   ┆           ┆        ┆ hlights   ┆ Feedback  │
# │            ┆ …          ┆ IST       ┆           ┆   ┆           ┆        ┆ excellen… ┆           │
# │ Generic    ┆ The review ┆ 2025-09-2 ┆ POSITIVE_ ┆ … ┆ 0.69851   ┆ merge  ┆ Both      ┆ App       │
# │ Positive   ┆ expresses  ┆ 8         ┆ EXPERIENC ┆   ┆           ┆        ┆ topics    ┆ inquiry   │
# │ Feedback   ┆ a positiv… ┆ 07:02:46  ┆ E         ┆   ┆           ┆        ┆ express a ┆           │
# │            ┆            ┆ IST       ┆           ┆   ┆           ┆        ┆ general … ┆           │
# │ Slow       ┆ The review ┆ 2025-10-2 ┆ FAST_DELI ┆ … ┆ 0.6936    ┆ merge  ┆ Both      ┆ Positive  │
# │ Delivery   ┆ indicates  ┆ 2         ┆ VERY      ┆   ┆           ┆        ┆ topics    ┆ Feedback  │
# │            ┆ a delay w… ┆ 14:19:24  ┆           ┆   ┆           ┆        ┆ express   ┆ and       │
# │            ┆            ┆ IST       ┆           ┆   ┆           ┆        ┆ positive  ┆ Experien… │
# │            ┆            ┆           ┆           ┆   ┆           ┆        ┆ s…        ┆           │
# │ App        ┆ The review ┆ 2025-10-2 ┆ GREAT_APP ┆ … ┆ 0.690503  ┆ new    ┆ The       ┆ App       │
# │ feedback   ┆ provides   ┆ 1         ┆           ┆   ┆           ┆        ┆ review    ┆ usability │
# │            ┆ generic    ┆ 20:13:31  ┆           ┆   ┆           ┆        ┆ expresses ┆ concern   │
# │            ┆ fe…        ┆ IST       ┆           ┆   ┆           ┆        ┆ frustrati ┆           │
# │            ┆            ┆           ┆           ┆   ┆           ┆        ┆ …         ┆           │
# └────────────┴────────────┴───────────┴───────────┴───┴───────────┴────────┴───────────┴───────────┘

# %% [markdown]
# ## Write Registry Update Draft

# %%
updates = []
timestamp = datetime.utcnow().isoformat() + 'Z'
for row in actions_df.iter_rows(named=True):
    updates.append({
        'timestamp': timestamp,
        'novel_label': row['novel_label'],
        'target_topic_id': row['best_topic_id'],
        'target_topic_name': row['best_topic_name'],
        'similarity': row['similarity'],
        'action': row['action'],
        'notes': row.get('notes'),
        'llm_label': row.get('llm_label'),
        'first_seen': row.get('first_seen'),
    })

updates_path = DATA_DIR / 'registry_updates.json'
with updates_path.open('w') as f:
    json.dump(updates, f, indent=2, default=str)
print(f'✓ Proposed updates written to {updates_path}')

review_path = DATA_DIR / 'registry_updates_preview.csv'
actions_df.write_csv(review_path)
print(f'  Preview CSV written to {review_path}')
# Out:
# ✓ Proposed updates written to ../data/registry_updates.json
#   Preview CSV written to ../data/registry_updates_preview.csv

# %% [markdown]
# ## Manual Follow-up
# - Review `data/registry_updates.json`
# - Apply merges/new topics in `registry/topic_registry.json`
# - Re-run topic routing if registry changes materially
